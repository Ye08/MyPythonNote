# %%
import requests

url = 'https://www.ptt.cc/bbs/movie/index.html'
response = requests.get(url)

print(response.text)  # result of setp-1
# Out:
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>看板 movie 文章列表 - 批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/v2.20/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/v2.20/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/v2.20/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/v2.20/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/v2.20/bbs-print.css" media="print">
#
#
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/v2.20/bbs.js"></script>
#
#
#
#
# <script type="text/javascript">
#
#   var _gaq = _gaq || [];
#   _gaq.push(['_setAccount', 'UA-32365737-1']);
#   _gaq.push(['_setDomainName', 'ptt.cc']);
#   _gaq.push(['_trackPageview']);
#
#   (function() {
#     var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
#     ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
#     var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
#   })();
#
# </script>
#
#
# 	</head>
#     <body>
#
# <div id="topbar-container">
# 	<div id="topbar" class="bbs-content">
# 		<a id="logo" href="/">批踢踢實業坊</a>
# 		<span>&rsaquo;</span>
# 		<a class="board" href="/bbs/movie/index.html"><span class="board-label">看板 </span>movie</a>
# 		<a class="right small" href="/about.html">關於我們</a>
# 		<a class="right small" href="/contact.html">聯絡資訊</a>
# 	</div>
# </div>
#
# <div id="main-container">
# 	<div id="action-bar-container">
# 		<div class="action-bar">
# 			<div class="btn-group btn-group-dir">
# 				<a class="btn selected" href="/bbs/movie/index.html">看板</a>
# 				<a class="btn" href="/man/movie/index.html">精華區</a>
# 			</div>
# 			<div class="btn-group btn-group-paging">
# 				<a class="btn wide" href="/bbs/movie/index1.html">最舊</a>
# 				<a class="btn wide" href="/bbs/movie/index4936.html">&lsaquo; 上頁</a>
# 				<a class="btn wide disabled">下頁 &rsaquo;</a>
# 				<a class="btn wide" href="/bbs/movie/index.html">最新</a>
# 			</div>
# 		</div>
# 	</div>
#
# 	<div class="r-list-container bbs-screen">
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/movie/M.1482338743.A.029.html">Re: [討論] 蜘蛛人自體噴絲是很成功的改編嗎？</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date">12/22</div>
# 				<div class="author">hong1126</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">10</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/movie/M.1482338934.A.640.html">[負雷] 星際過客 </a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date">12/22</div>
# 				<div class="author">takuminauki</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">17</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/movie/M.1482340217.A.418.html">[片單] 強加價值觀給他人的片</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date">12/22</div>
# 				<div class="author">tcps0428</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">2</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/movie/M.1482341385.A.7F6.html">[問片] 動畫真人交錯的電影？</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date">12/22</div>
# 				<div class="author">lorena409</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">18</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/movie/M.1482343549.A.BF2.html">[討論] 聽到某位演員,就可以聯想到他的口頭禪.</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date">12/22</div>
# 				<div class="author">Emerson158</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/movie/M.1482345630.A.808.html">[好雷] 比利林恩-好多框架之要進去還是要出來</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date">12/22</div>
# 				<div class="author">borntoeat</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">3</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/movie/M.1482351089.A.433.html">Re: [負雷]星際過客 爛到氣</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date">12/22</div>
# 				<div class="author">profound</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/movie/M.1482351482.A.81F.html">[好無雷] 星際過客 -- 尚可一看的星際愛情片</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date">12/22</div>
# 				<div class="author">profound</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">2</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/movie/M.1482352102.A.0E1.html">Re: [負雷]星際過客 爛到氣</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date">12/22</div>
# 				<div class="author">xu3ej04zj3</div>
# 			</div>
# 		</div>
#
#
#
#         <div class="r-list-sep"></div>
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">23</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/movie/M.1397887191.A.BD0.html">[公告]《各式疑難雜症FAQ》</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 4/19</div>
# 				<div class="author">yunyun85106</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f1">爆</span></div>
# 			<div class="mark">M</div>
# 			<div class="title">
#
# 				<a href="/bbs/movie/M.1468848054.A.77E.html">[公告] 板規！必看！｜好文推薦‧惡文檢舉</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 7/18</div>
# 				<div class="author">ericf129</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">4</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/movie/M.1480577115.A.AF0.html">[公告] 版主徵選公告</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date">12/01</div>
# 				<div class="author">pacificocean</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f1">爆</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/movie/M.1481013927.A.FCE.html">[贈票]擺渡人 梁朝偉X金城武 兩大男神送你上岸</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date">12/06</div>
# 				<div class="author">lcyspeaking</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f1">爆</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/movie/M.1481011438.A.B07.html">[贈票] 跨年首選【長城】台北特映會搶先看</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date">12/06</div>
# 				<div class="author">ChloeD</div>
# 			</div>
# 		</div>
#
#
#
# 	</div>
#
#
# </div>
#
#     </body>
# </html>

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.ptt.cc/bbs/movie/index.html'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'lxml')
articles = soup.find_all('div', 'r-ent')

print(articles)  # result of setp-2
# Out:
# [<div class="r-ent">
# <div class="nrec"></div>
# <div class="mark"></div>
# <div class="title">
# <a href="/bbs/movie/M.1482338743.A.029.html">Re: [討論] 蜘蛛人自體噴絲是很成功的改編嗎？</a>
# </div>
# <div class="meta">
# <div class="date">12/22</div>
# <div class="author">hong1126</div>
# </div>
# </div>, <div class="r-ent">
# <div class="nrec"><span class="hl f3">10</span></div>
# <div class="mark"></div>
# <div class="title">
# <a href="/bbs/movie/M.1482338934.A.640.html">[負雷] 星際過客 </a>
# </div>
# <div class="meta">
# <div class="date">12/22</div>
# <div class="author">takuminauki</div>
# </div>
# </div>, <div class="r-ent">
# <div class="nrec"><span class="hl f3">17</span></div>
# <div class="mark"></div>
# <div class="title">
# <a href="/bbs/movie/M.1482340217.A.418.html">[片單] 強加價值觀給他人的片</a>
# </div>
# <div class="meta">
# <div class="date">12/22</div>
# <div class="author">tcps0428</div>
# </div>
# </div>, <div class="r-ent">
# <div class="nrec"><span class="hl f2">2</span></div>
# <div class="mark"></div>
# <div class="title">
# <a href="/bbs/movie/M.1482341385.A.7F6.html">[問片] 動畫真人交錯的電影？</a>
# </div>
# <div class="meta">
# <div class="date">12/22</div>
# <div class="author">lorena409</div>
# </div>
# </div>, <div class="r-ent">
# <div class="nrec"><span class="hl f3">18</span></div>
# <div class="mark"></div>
# <div class="title">
# <a href="/bbs/movie/M.1482343549.A.BF2.html">[討論] 聽到某位演員,就可以聯想到他的口頭禪.</a>
# </div>
# <div class="meta">
# <div class="date">12/22</div>
# <div class="author">Emerson158</div>
# </div>
# </div>, <div class="r-ent">
# <div class="nrec"></div>
# <div class="mark"></div>
# <div class="title">
# <a href="/bbs/movie/M.1482345630.A.808.html">[好雷] 比利林恩-好多框架之要進去還是要出來</a>
# </div>
# <div class="meta">
# <div class="date">12/22</div>
# <div class="author">borntoeat</div>
# </div>
# </div>, <div class="r-ent">
# <div class="nrec"><span class="hl f2">3</span></div>
# <div class="mark"></div>
# <div class="title">
# <a href="/bbs/movie/M.1482351089.A.433.html">Re: [負雷]星際過客 爛到氣</a>
# </div>
# <div class="meta">
# <div class="date">12/22</div>
# <div class="author">profound</div>
# </div>
# </div>, <div class="r-ent">
# <div class="nrec"></div>
# <div class="mark"></div>
# <div class="title">
# <a href="/bbs/movie/M.1482351482.A.81F.html">[好無雷] 星際過客 -- 尚可一看的星際愛情片</a>
# </div>
# <div class="meta">
# <div class="date">12/22</div>
# <div class="author">profound</div>
# </div>
# </div>, <div class="r-ent">
# <div class="nrec"><span class="hl f2">2</span></div>
# <div class="mark"></div>
# <div class="title">
# <a href="/bbs/movie/M.1482352102.A.0E1.html">Re: [負雷]星際過客 爛到氣</a>
# </div>
# <div class="meta">
# <div class="date">12/22</div>
# <div class="author">xu3ej04zj3</div>
# </div>
# </div>, <div class="r-ent">
# <div class="nrec"><span class="hl f3">23</span></div>
# <div class="mark"></div>
# <div class="title">
# <a href="/bbs/movie/M.1397887191.A.BD0.html">[公告]《各式疑難雜症FAQ》</a>
# </div>
# <div class="meta">
# <div class="date"> 4/19</div>
# <div class="author">yunyun85106</div>
# </div>
# </div>, <div class="r-ent">
# <div class="nrec"><span class="hl f1">爆</span></div>
# <div class="mark">M</div>
# <div class="title">
# <a href="/bbs/movie/M.1468848054.A.77E.html">[公告] 板規！必看！｜好文推薦‧惡文檢舉</a>
# </div>
# <div class="meta">
# <div class="date"> 7/18</div>
# <div class="author">ericf129</div>
# </div>
# </div>, <div class="r-ent">
# <div class="nrec"><span class="hl f2">4</span></div>
# <div class="mark"></div>
# <div class="title">
# <a href="/bbs/movie/M.1480577115.A.AF0.html">[公告] 版主徵選公告</a>
# </div>
# <div class="meta">
# <div class="date">12/01</div>
# <div class="author">pacificocean</div>
# </div>
# </div>, <div class="r-ent">
# <div class="nrec"><span class="hl f1">爆</span></div>
# <div class="mark"></div>
# <div class="title">
# <a href="/bbs/movie/M.1481013927.A.FCE.html">[贈票]擺渡人 梁朝偉X金城武 兩大男神送你上岸</a>
# </div>
# <div class="meta">
# <div class="date">12/06</div>
# <div class="author">lcyspeaking</div>
# </div>
# </div>, <div class="r-ent">
# <div class="nrec"><span class="hl f1">爆</span></div>
# <div class="mark"></div>
# <div class="title">
# <a href="/bbs/movie/M.1481011438.A.B07.html">[贈票] 跨年首選【長城】台北特映會搶先看</a>
# </div>
# <div class="meta">
# <div class="date">12/06</div>
# <div class="author">ChloeD</div>
# </div>
# </div>]

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.ptt.cc/bbs/movie/index.html'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'lxml')
articles = soup.find_all('div', 'r-ent')

for article in articles:
    meta = article.find('div', 'title').find('a')

    title = meta.getText().strip()
    link = meta.get('href')
    push = article.find('div', 'nrec').getText()
    date = article.find('div', 'date').getText()
    author = article.find('div', 'author').getText()

    print(push, title, date, author)  # result of setp-3
# Out:
#  Re: [討論] 蜘蛛人自體噴絲是很成功的改編嗎？ 12/22 hong1126
# 10 [負雷] 星際過客 12/22 takuminauki
# 17 [片單] 強加價值觀給他人的片 12/22 tcps0428
# 2 [問片] 動畫真人交錯的電影？ 12/22 lorena409
# 18 [討論] 聽到某位演員,就可以聯想到他的口頭禪. 12/22 Emerson158
#  [好雷] 比利林恩-好多框架之要進去還是要出來 12/22 borntoeat
# 3 Re: [負雷]星際過客 爛到氣 12/22 profound
#  [好無雷] 星際過客 -- 尚可一看的星際愛情片 12/22 profound
# 2 Re: [負雷]星際過客 爛到氣 12/22 xu3ej04zj3
# 23 [公告]《各式疑難雜症FAQ》  4/19 yunyun85106
# 爆 [公告] 板規！必看！｜好文推薦‧惡文檢舉  7/18 ericf129
# 4 [公告] 版主徵選公告 12/01 pacificocean
# 爆 [贈票]擺渡人 梁朝偉X金城武 兩大男神送你上岸 12/06 lcyspeaking
# 爆 [贈票] 跨年首選【長城】台北特映會搶先看 12/06 ChloeD
